# %%
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
import scipy
from scipy.stats import bayes_mvs as bayesest
import moviepy.editor as mpy
import os #Lib for get the operative system sintaxis

# %%
doubling_time=18

# %%
data1=pd.read_csv("./dataCRM1.csv")
timearray1=data1.time.unique()

mnszarray1=[]
cvszarray1=[]
errcv2szarray1=[]
errmnszarray1=[]
df=data1
del df['time']
for m in range(len(df)):
    szs=df.loc[m, :].values.tolist()
    mean_cntr, var_cntr, std_cntr = bayesest(szs,alpha=0.95)
    mnszarray1.append(np.mean(szs))
    errmnszarray1.append(mean_cntr[1][1]-mean_cntr[0])
    cvszarray1.append(np.var(szs)/np.mean(szs)**2)
    errv=(var_cntr[1][1]-var_cntr[0])/mean_cntr[0]**2+2*(mean_cntr[1][1]-mean_cntr[0])*var_cntr[0]/mean_cntr[0]**3
    errcv2szarray1.append(errv)

# %%
# %matplotlib agg
if not os.path.exists('./figures1'):
    os.makedirs('./figures1') #Figures path
data1=pd.read_csv("./dataCRM1.csv")
n=1
for l in range(70):
    df=data1.iloc[l]
    t=df['time']/18
    del df['time']
    plt.clf()
    
    fig, ax = plt.subplots(2,1, figsize=(5,5))
    ax[0].plot(np.array(timearray1)/doubling_time,mnszarray1,lw=2)
    ax[0].fill_between(np.array(timearray1)/doubling_time,np.array(mnszarray1)-np.array(errmnszarray1),np.array(mnszarray1)
                   +np.array(errmnszarray1),alpha=1, edgecolor='#4db8ff', facecolor='#4db8ff',linewidth=0,label="SSA")
    ax[0].set_xlim(0,7)
    ax[0].plot([t,t],[1,1.7],ls="--",lw=1,c='k')

    counts,values = np.histogram(df,bins=np.linspace(0.5,3,100))
    ax[1].vlines(values, 0, counts/5000, color='#009447', lw=4)
    mn=np.mean(df)
    std=np.std(df)
    #sumi=np.sum(np.array(pop)[:,4])
    ax[1].plot([mn,mn],[0,0.9],c='k',lw=2)
    ax[1].plot([mn-std,mn+std],[0.7,0.7],c='k',lw=2)
    ax[1].text(mn-0.1,1.0,"mean",fontsize=12)
    #ax[1].arrow(mn, 0.8, std, 0,width=0.002,color='k')
    #ax[1].arrow(mn, 0.8, -std, 0,width=0.002,color='k')
    
    ax[1].set_xlim(0,3)
    ax[1].set_ylim(0,1.2)
    ax[0].set_xlabel(r'$t/\tau$',fontsize=12)
    ax[0].set_ylabel("$s$ (fl)",fontsize=12)
    ax[1].set_xlabel("$s$ (fl)",fontsize=12)
    ax[1].set_ylabel(r'$\rho(s)$',fontsize=12)
    ax[1].text(2.3,1.1,r'$t/\tau=%.1f$'%t,fontsize=12)
    plt.subplots_adjust(hspace=0.5,wspace=0.2)
    for m in [0,1]:
        ax[m].grid()
        ax[m].tick_params(axis='x', labelsize=12)
        ax[m].tick_params(axis='y', labelsize=12)
        for axis in ['bottom','left']:
            ax[m].spines[axis].set_linewidth(2)
            ax[m].tick_params(axis='both', width=2,length=6)
        for axis in ['top','right']:
            ax[m].spines[axis].set_linewidth(0)
            ax[m].tick_params(axis='both', width=0,length=6)
    
    plt.savefig('./figures1/'+str(n+10000)+'.jpg',bbox_inches='tight')
    n+=1

# %%
image_folder = './figures1'
video_name = './figures1/video.mp4'

images = [img for img in os.listdir(image_folder) if img.endswith(".jpg")]
frame = cv2.imread(os.path.join(image_folder, images[0]))
height, width, layers = frame.shape

video = cv2.VideoWriter(video_name, cv2.VideoWriter_fourcc(*'MP4V'), 5, (width,height))

for image in images:
    video.write(cv2.imread(os.path.join(image_folder, image)))

cv2.destroyAllWindows()
video.release()

# %%
data1=pd.read_csv("./dataCRM2.csv")
timearray1=data1.time.unique()

mnszarray1=[]
cvszarray1=[]
errcv2szarray1=[]
errmnszarray1=[]
df=data1
del df['time']
for m in range(len(df)):
    szs=df.loc[m, :].values.tolist()
    mean_cntr, var_cntr, std_cntr = bayesest(szs,alpha=0.95)
    mnszarray1.append(np.mean(szs))
    errmnszarray1.append(mean_cntr[1][1]-mean_cntr[0])
    cvszarray1.append(np.var(szs)/np.mean(szs)**2)
    errv=(var_cntr[1][1]-var_cntr[0])/mean_cntr[0]**2+2*(mean_cntr[1][1]-mean_cntr[0])*var_cntr[0]/mean_cntr[0]**3
    errcv2szarray1.append(errv)

# %%
# %matplotlib agg
if not os.path.exists('./figures2'):
    os.makedirs('./figures2') #Figures path
data1=pd.read_csv("./dataCRM2.csv")
n=1
for l in range(70):
    df=data1.iloc[l]
    t=df['time']/18
    del df['time']
    plt.clf()
    
    fig, ax = plt.subplots(2,1, figsize=(5,5))
    ax[0].plot(np.array(timearray1)/doubling_time,mnszarray1,lw=2)
    ax[0].fill_between(np.array(timearray1)/doubling_time,np.array(mnszarray1)-np.array(errmnszarray1),np.array(mnszarray1)
                   +np.array(errmnszarray1),alpha=1, edgecolor='#4db8ff', facecolor='#4db8ff',linewidth=0,label="SSA")
    ax[0].set_xlim(0,7)
    ax[0].plot([t,t],[1,1.7],ls="--",lw=1,c='k')

    counts,values = np.histogram(df,bins=np.linspace(0.5,3,80),normed=True)
    ax[1].vlines(values, 0, counts, color='#009447', lw=4)
    mn=np.mean(df)
    std=np.std(df)
    #sumi=np.sum(np.array(pop)[:,4])
    ax[1].plot([mn,mn],[0,2.9],c='k',lw=2)
    ax[1].text(mn-0.1,2.95,"mean",fontsize=12)
    ax[1].plot([mn-std,mn+std],[1.6,1.6],c='k',lw=2)
    #ax[1].arrow(mn, 1.8, std, 0,width=0.002,color='k')
    #ax[1].arrow(mn, 1.8, -std, 0,width=0.002,color='k')
    
    ax[1].set_xlim(0,3)
    ax[1].set_ylim(0,3)
    ax[0].set_xlabel(r'$t/\tau$',fontsize=12)
    ax[0].set_ylabel("$s$ (fl)",fontsize=12)
    ax[1].set_xlabel("$s$ (fl)",fontsize=12)
    ax[1].set_ylabel(r'$\rho(s)$',fontsize=12)
    ax[1].text(2.3,2.9,r'$t/\tau=%.1f$'%t,fontsize=12)
    plt.subplots_adjust(hspace=0.5,wspace=0.2)
    for m in [0,1]:
        ax[m].grid()
        ax[m].tick_params(axis='x', labelsize=12)
        ax[m].tick_params(axis='y', labelsize=12)
        for axis in ['bottom','left']:
            ax[m].spines[axis].set_linewidth(2)
            ax[m].tick_params(axis='both', width=2,length=6)
        for axis in ['top','right']:
            ax[m].spines[axis].set_linewidth(0)
            ax[m].tick_params(axis='both', width=0,length=6)
    
    plt.savefig('./figures2/'+str(n+10000)+'.jpg',bbox_inches='tight')
    n+=1

# %%
image_folder = './figures2'
video_name = './figures2/video.mp4'

images = [img for img in os.listdir(image_folder) if img.endswith(".jpg")]
frame = cv2.imread(os.path.join(image_folder, images[0]))
height, width, layers = frame.shape

video = cv2.VideoWriter(video_name, cv2.VideoWriter_fourcc(*'MP4V'), 5, (width,height))

for image in images:
    video.write(cv2.imread(os.path.join(image_folder, image)))

cv2.destroyAllWindows()
video.release()

# %%
data1=pd.read_csv("./dataCRM3.csv")
timearray1=data1.time.unique()

mnszarray1=[]
cvszarray1=[]
errcv2szarray1=[]
errmnszarray1=[]
df=data1
del df['time']
for m in range(len(df)):
    szs=df.loc[m, :].values.tolist()
    mean_cntr, var_cntr, std_cntr = bayesest(szs,alpha=0.95)
    mnszarray1.append(np.mean(szs))
    errmnszarray1.append(mean_cntr[1][1]-mean_cntr[0])
    cvszarray1.append(np.var(szs)/np.mean(szs)**2)
    errv=(var_cntr[1][1]-var_cntr[0])/mean_cntr[0]**2+2*(mean_cntr[1][1]-mean_cntr[0])*var_cntr[0]/mean_cntr[0]**3
    errcv2szarray1.append(errv)

# %%
# %matplotlib agg
if not os.path.exists('./figures3'):
    os.makedirs('./figures3') #Figures path
data1=pd.read_csv("./dataCRM3.csv")
n=1
for l in range(100):
    df=data1.iloc[l]
    t=df['time']/18
    del df['time']
    plt.clf()
    
    fig, ax = plt.subplots(2,1, figsize=(5,5))
    ax[0].plot(np.array(timearray1)/doubling_time,mnszarray1,lw=2)
    ax[0].fill_between(np.array(timearray1)/doubling_time,np.array(mnszarray1)-np.array(errmnszarray1),np.array(mnszarray1)
                   +np.array(errmnszarray1),alpha=1, edgecolor='#4db8ff', facecolor='#4db8ff',linewidth=0,label="SSA")
    ax[0].set_xlim(0,10)
    ax[0].plot([t,t],[1,1.7],ls="--",lw=1,c='k')

    counts,values = np.histogram(df,bins=np.linspace(0.5,3,80),normed=True)
    ax[1].vlines(values, 0, counts, color='#009447', lw=4)
    mn=np.mean(df)
    std=np.std(df)
    #sumi=np.sum(np.array(pop)[:,4])
    ax[1].plot([mn,mn],[0,2.9],c='k',lw=2)
    #ax[1].text(mn-0.1,2.95,"mean",fontsize=10)
    ax[1].text(mn-0.1,2.95,"mean",fontsize=12)
    ax[1].plot([mn-std,mn+std],[1.6,1.6],c='k',lw=2)
    
    ax[1].set_xlim(0,3)
    ax[1].set_ylim(0,3)
    ax[0].set_xlabel(r'$t/\tau$',fontsize=12)
    ax[0].set_ylabel("$s$ (fl)",fontsize=12)
    ax[1].set_xlabel("$s$ (fl)",fontsize=12)
    ax[1].set_ylabel(r'$\rho(s)$',fontsize=12)
    ax[1].text(2.3,2.9,r'$t/\tau=%.1f$'%t,fontsize=12)
    plt.subplots_adjust(hspace=0.5,wspace=0.2)
    for m in [0,1]:
        ax[m].grid()
        ax[m].tick_params(axis='x', labelsize=12)
        ax[m].tick_params(axis='y', labelsize=12)
        for axis in ['bottom','left']:
            ax[m].spines[axis].set_linewidth(2)
            ax[m].tick_params(axis='both', width=2,length=6)
        for axis in ['top','right']:
            ax[m].spines[axis].set_linewidth(0)
            ax[m].tick_params(axis='both', width=0,length=6)
    
    plt.savefig('./figures3/'+str(n+10000)+'.jpg',bbox_inches='tight')
    n+=1

# %%
image_folder = './figures3'
video_name = './figures3/video.mp4'

images = [img for img in os.listdir(image_folder) if img.endswith(".jpg")]
frame = cv2.imread(os.path.join(image_folder, images[0]))
height, width, layers = frame.shape

video = cv2.VideoWriter(video_name, cv2.VideoWriter_fourcc(*'MP4V'), 5, (width,height))

for image in images:
    video.write(cv2.imread(os.path.join(image_folder, image)))

cv2.destroyAllWindows()
video.release()
